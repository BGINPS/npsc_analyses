# %%
# %load_ext autoreload
# %autoreload 2
import sys
import os
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib as mpl
mpl.rcParams['pdf.fonttype'] = 42
mpl.rcParams['ps.fonttype'] = 42
mpl.rcParams['font.sans-serif'] = "Arial"
mpl.rcParams['font.family'] = "sans-serif"
import time
import numpy as np
import glob
import re
import random
import torch

sys.path.insert(0, '/Data/user/panhailin/git_lab/npspy')
import npspy as nps
from npspy import npsc

# %%
sim = 'sim5'

# %%
for iteration in range(1,4):
    npsc.clean_ref_obj_by_ae_and_save(
        obj=f'../../03.results/simulation/{sim}/{sim}.pkl',
        fit_name=f'{sim}_iter{iteration}',
        output_save_dir=f'../../03.results/simulation/{sim}/iter{iteration}',
        save_reconstruction=False,
        max_iteration=iteration,
        epochs=20,
    )
# Out:
# Iteration 1/1 for training ShapeAwareAutoencoder...
# Model ShapeAwareAutoencoder has total parameter number: 1.02 M
# Epoch   0 / 20 train_loss: 0.019905 | val_loss: 0.004542 | lr: 0.001
# Epoch   1 / 20 train_loss: 0.003531 | val_loss: 0.005414 | lr: 0.001
# Epoch   2 / 20 train_loss: 0.002292 | val_loss: 0.004551 | lr: 0.001
# Epoch   3 / 20 train_loss: 0.001953 | val_loss: 0.002460 | lr: 0.001
# Epoch   4 / 20 train_loss: 0.001549 | val_loss: 0.001016 | lr: 0.001
# Epoch   5 / 20 train_loss: 0.001161 | val_loss: 0.003219 | lr: 0.001
# Epoch   6 / 20 train_loss: 0.001299 | val_loss: 0.000916 | lr: 0.001
# Epoch   7 / 20 train_loss: 0.001041 | val_loss: 0.001526 | lr: 0.001
# Epoch   8 / 20 train_loss: 0.001118 | val_loss: 0.001133 | lr: 0.001
# Epoch   9 / 20 train_loss: 0.000970 | val_loss: 0.001235 | lr: 0.001
# Epoch  10 / 20 train_loss: 0.000929 | val_loss: 0.001298 | lr: 0.0005
# Epoch  11 / 20 train_loss: 0.000777 | val_loss: 0.000867 | lr: 0.0005
# Epoch  12 / 20 train_loss: 0.000734 | val_loss: 0.000882 | lr: 0.0005
# Epoch  13 / 20 train_loss: 0.000778 | val_loss: 0.001037 | lr: 0.0005
# Epoch  14 / 20 train_loss: 0.000755 | val_loss: 0.001022 | lr: 0.0005
# Epoch  15 / 20 train_loss: 0.000751 | val_loss: 0.001407 | lr: 0.00025
# Epoch  16 / 20 train_loss: 0.000651 | val_loss: 0.000700 | lr: 0.00025
# Epoch  17 / 20 train_loss: 0.000653 | val_loss: 0.000636 | lr: 0.00025
# Epoch  18 / 20 train_loss: 0.000650 | val_loss: 0.000871 | lr: 0.00025
# Epoch  19 / 20 train_loss: 0.000621 | val_loss: 0.000579 | lr: 0.00025
# Model saved to sim5_iter1_best_model.pth
# Model ShapeAwareAutoencoder has total parameter number: 1.02 M
# MAD cutoff for reconstruction error: 0.0005933462525717914
# MAD cutoff for Lzc: 79.0
# Number of inconsistent reads: 5100
# Number of clean reads: 14900
# Iteration 1/2 for training ShapeAwareAutoencoder...
# Model ShapeAwareAutoencoder has total parameter number: 1.02 M
# Epoch   0 / 20 train_loss: 0.019905 | val_loss: 0.004542 | lr: 0.001
# Epoch   1 / 20 train_loss: 0.003531 | val_loss: 0.005414 | lr: 0.001
# Epoch   2 / 20 train_loss: 0.002292 | val_loss: 0.004551 | lr: 0.001
# Epoch   3 / 20 train_loss: 0.001953 | val_loss: 0.002460 | lr: 0.001
# Epoch   4 / 20 train_loss: 0.001549 | val_loss: 0.001016 | lr: 0.001
# Epoch   5 / 20 train_loss: 0.001161 | val_loss: 0.003219 | lr: 0.001
# Epoch   6 / 20 train_loss: 0.001299 | val_loss: 0.000916 | lr: 0.001
# Epoch   7 / 20 train_loss: 0.001041 | val_loss: 0.001526 | lr: 0.001
# Epoch   8 / 20 train_loss: 0.001118 | val_loss: 0.001133 | lr: 0.001
# Epoch   9 / 20 train_loss: 0.000970 | val_loss: 0.001235 | lr: 0.001
# Epoch  10 / 20 train_loss: 0.000929 | val_loss: 0.001298 | lr: 0.0005
# Epoch  11 / 20 train_loss: 0.000777 | val_loss: 0.000867 | lr: 0.0005
# Epoch  12 / 20 train_loss: 0.000734 | val_loss: 0.000882 | lr: 0.0005
# Epoch  13 / 20 train_loss: 0.000778 | val_loss: 0.001037 | lr: 0.0005
# Epoch  14 / 20 train_loss: 0.000755 | val_loss: 0.001022 | lr: 0.0005
# Epoch  15 / 20 train_loss: 0.000751 | val_loss: 0.001407 | lr: 0.00025
# Epoch  16 / 20 train_loss: 0.000651 | val_loss: 0.000700 | lr: 0.00025
# Epoch  17 / 20 train_loss: 0.000653 | val_loss: 0.000636 | lr: 0.00025
# Epoch  18 / 20 train_loss: 0.000650 | val_loss: 0.000871 | lr: 0.00025
# Epoch  19 / 20 train_loss: 0.000621 | val_loss: 0.000579 | lr: 0.00025
# Iteration 2/2 for training ShapeAwareAutoencoder...
# Model ShapeAwareAutoencoder has total parameter number: 1.02 M
# Epoch   0 / 20 train_loss: 0.001214 | val_loss: 0.001838 | lr: 0.001
# Epoch   1 / 20 train_loss: 0.000719 | val_loss: 0.000635 | lr: 0.001
# Epoch   2 / 20 train_loss: 0.000660 | val_loss: 0.000881 | lr: 0.001
# Epoch   3 / 20 train_loss: 0.000623 | val_loss: 0.001140 | lr: 0.001
# Epoch   4 / 20 train_loss: 0.000584 | val_loss: 0.000620 | lr: 0.001
# Epoch   5 / 20 train_loss: 0.000648 | val_loss: 0.000729 | lr: 0.001
# Epoch   6 / 20 train_loss: 0.000638 | val_loss: 0.000909 | lr: 0.001
# Epoch   7 / 20 train_loss: 0.000728 | val_loss: 0.000682 | lr: 0.001
# Epoch   8 / 20 train_loss: 0.000825 | val_loss: 0.000576 | lr: 0.001
# Epoch   9 / 20 train_loss: 0.000614 | val_loss: 0.000833 | lr: 0.001
# Epoch  10 / 20 train_loss: 0.000578 | val_loss: 0.001037 | lr: 0.001
# Epoch  11 / 20 train_loss: 0.000634 | val_loss: 0.000517 | lr: 0.001
# Epoch  12 / 20 train_loss: 0.000592 | val_loss: 0.000519 | lr: 0.001
# Epoch  13 / 20 train_loss: 0.000530 | val_loss: 0.000736 | lr: 0.001
# Epoch  14 / 20 train_loss: 0.000526 | val_loss: 0.000864 | lr: 0.001
# Epoch  15 / 20 train_loss: 0.000511 | val_loss: 0.000944 | lr: 0.0005
# Epoch  16 / 20 train_loss: 0.000461 | val_loss: 0.000493 | lr: 0.0005
# Epoch  17 / 20 train_loss: 0.000472 | val_loss: 0.000427 | lr: 0.0005
# Epoch  18 / 20 train_loss: 0.000462 | val_loss: 0.000447 | lr: 0.0005
# Epoch  19 / 20 train_loss: 0.000461 | val_loss: 0.000425 | lr: 0.0005
# Model saved to sim5_iter2_best_model.pth
# Model ShapeAwareAutoencoder has total parameter number: 1.02 M
# MAD cutoff for reconstruction error: 0.000506632262840867
# MAD cutoff for Lzc: 79.0
# Number of inconsistent reads: 5203
# Number of clean reads: 14797
# Iteration 1/3 for training ShapeAwareAutoencoder...
# Model ShapeAwareAutoencoder has total parameter number: 1.02 M
# Epoch   0 / 20 train_loss: 0.019905 | val_loss: 0.004542 | lr: 0.001
# Epoch   1 / 20 train_loss: 0.003531 | val_loss: 0.005414 | lr: 0.001
# Epoch   2 / 20 train_loss: 0.002292 | val_loss: 0.004551 | lr: 0.001
# Epoch   3 / 20 train_loss: 0.001953 | val_loss: 0.002460 | lr: 0.001
# Epoch   4 / 20 train_loss: 0.001549 | val_loss: 0.001016 | lr: 0.001
# Epoch   5 / 20 train_loss: 0.001161 | val_loss: 0.003219 | lr: 0.001
# Epoch   6 / 20 train_loss: 0.001299 | val_loss: 0.000916 | lr: 0.001
# Epoch   7 / 20 train_loss: 0.001041 | val_loss: 0.001526 | lr: 0.001
# Epoch   8 / 20 train_loss: 0.001118 | val_loss: 0.001133 | lr: 0.001
# Epoch   9 / 20 train_loss: 0.000970 | val_loss: 0.001235 | lr: 0.001
# Epoch  10 / 20 train_loss: 0.000929 | val_loss: 0.001298 | lr: 0.0005
# Epoch  11 / 20 train_loss: 0.000777 | val_loss: 0.000867 | lr: 0.0005
# Epoch  12 / 20 train_loss: 0.000734 | val_loss: 0.000882 | lr: 0.0005
# Epoch  13 / 20 train_loss: 0.000778 | val_loss: 0.001037 | lr: 0.0005
# Epoch  14 / 20 train_loss: 0.000755 | val_loss: 0.001022 | lr: 0.0005
# Epoch  15 / 20 train_loss: 0.000751 | val_loss: 0.001407 | lr: 0.00025
# Epoch  16 / 20 train_loss: 0.000651 | val_loss: 0.000700 | lr: 0.00025
# Epoch  17 / 20 train_loss: 0.000653 | val_loss: 0.000636 | lr: 0.00025
# Epoch  18 / 20 train_loss: 0.000650 | val_loss: 0.000871 | lr: 0.00025
# Epoch  19 / 20 train_loss: 0.000621 | val_loss: 0.000579 | lr: 0.00025
# Iteration 2/3 for training ShapeAwareAutoencoder...
# Model ShapeAwareAutoencoder has total parameter number: 1.02 M
# Epoch   0 / 20 train_loss: 0.001214 | val_loss: 0.001838 | lr: 0.001
# Epoch   1 / 20 train_loss: 0.000719 | val_loss: 0.000635 | lr: 0.001
# Epoch   2 / 20 train_loss: 0.000660 | val_loss: 0.000881 | lr: 0.001
# Epoch   3 / 20 train_loss: 0.000623 | val_loss: 0.001140 | lr: 0.001
# Epoch   4 / 20 train_loss: 0.000584 | val_loss: 0.000620 | lr: 0.001
# Epoch   5 / 20 train_loss: 0.000648 | val_loss: 0.000729 | lr: 0.001
# Epoch   6 / 20 train_loss: 0.000638 | val_loss: 0.000909 | lr: 0.001
# Epoch   7 / 20 train_loss: 0.000728 | val_loss: 0.000682 | lr: 0.001
# Epoch   8 / 20 train_loss: 0.000825 | val_loss: 0.000576 | lr: 0.001
# Epoch   9 / 20 train_loss: 0.000614 | val_loss: 0.000833 | lr: 0.001
# Epoch  10 / 20 train_loss: 0.000578 | val_loss: 0.001037 | lr: 0.001
# Epoch  11 / 20 train_loss: 0.000634 | val_loss: 0.000517 | lr: 0.001
# Epoch  12 / 20 train_loss: 0.000592 | val_loss: 0.000519 | lr: 0.001
# Epoch  13 / 20 train_loss: 0.000530 | val_loss: 0.000736 | lr: 0.001
# Epoch  14 / 20 train_loss: 0.000526 | val_loss: 0.000864 | lr: 0.001
# Epoch  15 / 20 train_loss: 0.000511 | val_loss: 0.000944 | lr: 0.0005
# Epoch  16 / 20 train_loss: 0.000461 | val_loss: 0.000493 | lr: 0.0005
# Epoch  17 / 20 train_loss: 0.000472 | val_loss: 0.000427 | lr: 0.0005
# Epoch  18 / 20 train_loss: 0.000462 | val_loss: 0.000447 | lr: 0.0005
# Epoch  19 / 20 train_loss: 0.000461 | val_loss: 0.000425 | lr: 0.0005
# Iteration 3/3 for training ShapeAwareAutoencoder...
# Model ShapeAwareAutoencoder has total parameter number: 1.02 M
# Epoch   0 / 20 train_loss: 0.001012 | val_loss: 0.000551 | lr: 0.001
# Epoch   1 / 20 train_loss: 0.000523 | val_loss: 0.000649 | lr: 0.001
# Epoch   2 / 20 train_loss: 0.000471 | val_loss: 0.000781 | lr: 0.001
# Epoch   3 / 20 train_loss: 0.000464 | val_loss: 0.000561 | lr: 0.001
# Epoch   4 / 20 train_loss: 0.000462 | val_loss: 0.000454 | lr: 0.001
# Epoch   5 / 20 train_loss: 0.000466 | val_loss: 0.000511 | lr: 0.001
# Epoch   6 / 20 train_loss: 0.000470 | val_loss: 0.000439 | lr: 0.001
# Epoch   7 / 20 train_loss: 0.000468 | val_loss: 0.000466 | lr: 0.001
# Epoch   8 / 20 train_loss: 0.000498 | val_loss: 0.000526 | lr: 0.001
# Epoch   9 / 20 train_loss: 0.000506 | val_loss: 0.000451 | lr: 0.001
# Epoch  10 / 20 train_loss: 0.000464 | val_loss: 0.000493 | lr: 0.0005
# Epoch  11 / 20 train_loss: 0.000420 | val_loss: 0.000428 | lr: 0.0005
# Epoch  12 / 20 train_loss: 0.000419 | val_loss: 0.000418 | lr: 0.0005
# Epoch  13 / 20 train_loss: 0.000422 | val_loss: 0.000416 | lr: 0.0005
# Epoch  14 / 20 train_loss: 0.000421 | val_loss: 0.000534 | lr: 0.0005
# Epoch  15 / 20 train_loss: 0.000412 | val_loss: 0.000394 | lr: 0.0005
# Epoch  16 / 20 train_loss: 0.000411 | val_loss: 0.000444 | lr: 0.0005
# Epoch  17 / 20 train_loss: 0.000425 | val_loss: 0.000395 | lr: 0.0005
# Epoch  18 / 20 train_loss: 0.000411 | val_loss: 0.000393 | lr: 0.0005
# Epoch  19 / 20 train_loss: 0.000419 | val_loss: 0.000430 | lr: 0.0005
# Model saved to sim5_iter3_best_model.pth
# Model ShapeAwareAutoencoder has total parameter number: 1.02 M
# MAD cutoff for reconstruction error: 0.0005060274852439761
# MAD cutoff for Lzc: 79.0
# Number of inconsistent reads: 4954
# Number of clean reads: 15046

# %%
cm_dfs_dict = {}
for iteration in range(1,4):
    cm_df = npsc.get_cm_from_errors_for_sim(f'../../03.results/simulation/{sim}/iter{iteration}/{sim}_iter{iteration}_error.csv')
    cm_dfs_dict[iteration] = cm_df
cm_dfs_dict
# Out:
# {1: pred    target  noise
#  true
#  target   17792    208
#  noise      208   1792,
#  2: pred    target  noise
#  true
#  target   18000      0
#  noise        0   2000,
#  3: pred    target  noise
#  true
#  target   18000      0
#  noise        0   2000}

# %%
for iteration, cm_df in cm_dfs_dict.items():
    nps.ml.plot_cm(cm_df, figsize=(2, 1.7), annot_size=12.0)
    plt.xticks(fontsize=12)
    plt.yticks(fontsize=12)
    plt.savefig(f"../../05.figures/simulation/{sim}/{sim}_iter{iteration}_cm.pdf", bbox_inches='tight')

# %%
metrics_dfs = []
for iteration in range(1,4):
    metrics_df = npsc.get_metrics_from_errors_for_sim(f'../../03.results/simulation/{sim}/iter{iteration}/{sim}_iter{iteration}_error.csv')
    metrics_df.index = [f'iter{iteration}']
    metrics_dfs.append(metrics_df)
metrics_dfs = pd.concat(metrics_dfs)
metrics_dfs
# Out:
#        accuracy  precision    recall  f1_score  jaccard_score
# iter1    0.9792   0.942222  0.942222  0.942222       0.894374
# iter2    1.0000   1.000000  1.000000  1.000000       1.000000
# iter3    1.0000   1.000000  1.000000  1.000000       1.000000

# %%
npsc.draw_radar_plot(metrics_dfs, y_min=0.80, legned_ncol=1, figsize=(4,4), y_tick_num=4)
plt.savefig(f'../../05.figures/simulation/{sim}/{sim}_radar_plot.pdf', bbox_inches='tight')
