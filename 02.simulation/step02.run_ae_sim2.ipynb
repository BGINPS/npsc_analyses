# %%
# %load_ext autoreload
# %autoreload 2
import sys
import os
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib as mpl
mpl.rcParams['pdf.fonttype'] = 42
mpl.rcParams['ps.fonttype'] = 42
mpl.rcParams['font.sans-serif'] = "Arial"
mpl.rcParams['font.family'] = "sans-serif"
import time
import numpy as np
import glob
import re
import random
import torch

sys.path.insert(0, '/Data/user/panhailin/git_lab/npspy')
import npspy as nps
from npspy import npsc

# %%
sim = 'sim2'

# %%
for iteration in range(1,4):
    npsc.clean_ref_obj_by_ae_and_save(
        obj=f'../../03.results/simulation/{sim}/{sim}.pkl',
        fit_name=f'{sim}_iter{iteration}',
        output_save_dir=f'../../03.results/simulation/{sim}/iter{iteration}',
        save_reconstruction=False,
        max_iteration=iteration,
        epochs=20,
    )
# Out:
# Iteration 1/1 for training ShapeAwareAutoencoder...
# Model ShapeAwareAutoencoder has total parameter number: 1.02 M
# Epoch   0 / 20 train_loss: 0.025793 | val_loss: 0.006027 | lr: 0.001
# Epoch   1 / 20 train_loss: 0.005020 | val_loss: 0.006074 | lr: 0.001
# Epoch   2 / 20 train_loss: 0.004281 | val_loss: 0.003866 | lr: 0.001
# Epoch   3 / 20 train_loss: 0.003842 | val_loss: 0.005754 | lr: 0.001
# Epoch   4 / 20 train_loss: 0.003455 | val_loss: 0.002888 | lr: 0.001
# Epoch   5 / 20 train_loss: 0.002686 | val_loss: 0.003624 | lr: 0.001
# Epoch   6 / 20 train_loss: 0.002528 | val_loss: 0.002586 | lr: 0.001
# Epoch   7 / 20 train_loss: 0.002452 | val_loss: 0.004894 | lr: 0.001
# Epoch   8 / 20 train_loss: 0.002121 | val_loss: 0.002456 | lr: 0.001
# Epoch   9 / 20 train_loss: 0.001765 | val_loss: 0.002761 | lr: 0.001
# Epoch  10 / 20 train_loss: 0.001796 | val_loss: 0.001643 | lr: 0.001
# Epoch  11 / 20 train_loss: 0.001683 | val_loss: 0.001452 | lr: 0.001
# Epoch  12 / 20 train_loss: 0.001684 | val_loss: 0.001415 | lr: 0.001
# Epoch  13 / 20 train_loss: 0.001645 | val_loss: 0.001599 | lr: 0.001
# Epoch  14 / 20 train_loss: 0.001864 | val_loss: 0.002920 | lr: 0.001
# Epoch  15 / 20 train_loss: 0.001590 | val_loss: 0.001400 | lr: 0.001
# Epoch  16 / 20 train_loss: 0.001700 | val_loss: 0.001677 | lr: 0.001
# Epoch  17 / 20 train_loss: 0.001664 | val_loss: 0.006599 | lr: 0.001
# Epoch  18 / 20 train_loss: 0.001671 | val_loss: 0.001390 | lr: 0.001
# Epoch  19 / 20 train_loss: 0.001438 | val_loss: 0.001242 | lr: 0.001
# Model saved to sim2_iter1_best_model.pth
# Model ShapeAwareAutoencoder has total parameter number: 1.02 M
# MAD cutoff for reconstruction error: 0.0008386753615923226
# MAD cutoff for Lzc: 79.0
# Number of inconsistent reads: 5079
# Number of clean reads: 14921
# Iteration 1/2 for training ShapeAwareAutoencoder...
# Model ShapeAwareAutoencoder has total parameter number: 1.02 M
# Epoch   0 / 20 train_loss: 0.025793 | val_loss: 0.006027 | lr: 0.001
# Epoch   1 / 20 train_loss: 0.005020 | val_loss: 0.006074 | lr: 0.001
# Epoch   2 / 20 train_loss: 0.004281 | val_loss: 0.003866 | lr: 0.001
# Epoch   3 / 20 train_loss: 0.003842 | val_loss: 0.005754 | lr: 0.001
# Epoch   4 / 20 train_loss: 0.003455 | val_loss: 0.002888 | lr: 0.001
# Epoch   5 / 20 train_loss: 0.002686 | val_loss: 0.003624 | lr: 0.001
# Epoch   6 / 20 train_loss: 0.002528 | val_loss: 0.002586 | lr: 0.001
# Epoch   7 / 20 train_loss: 0.002452 | val_loss: 0.004894 | lr: 0.001
# Epoch   8 / 20 train_loss: 0.002121 | val_loss: 0.002456 | lr: 0.001
# Epoch   9 / 20 train_loss: 0.001765 | val_loss: 0.002761 | lr: 0.001
# Epoch  10 / 20 train_loss: 0.001796 | val_loss: 0.001643 | lr: 0.001
# Epoch  11 / 20 train_loss: 0.001683 | val_loss: 0.001452 | lr: 0.001
# Epoch  12 / 20 train_loss: 0.001684 | val_loss: 0.001415 | lr: 0.001
# Epoch  13 / 20 train_loss: 0.001645 | val_loss: 0.001599 | lr: 0.001
# Epoch  14 / 20 train_loss: 0.001864 | val_loss: 0.002920 | lr: 0.001
# Epoch  15 / 20 train_loss: 0.001590 | val_loss: 0.001400 | lr: 0.001
# Epoch  16 / 20 train_loss: 0.001700 | val_loss: 0.001677 | lr: 0.001
# Epoch  17 / 20 train_loss: 0.001664 | val_loss: 0.006599 | lr: 0.001
# Epoch  18 / 20 train_loss: 0.001671 | val_loss: 0.001390 | lr: 0.001
# Epoch  19 / 20 train_loss: 0.001438 | val_loss: 0.001242 | lr: 0.001
# Iteration 2/2 for training ShapeAwareAutoencoder...
# Model ShapeAwareAutoencoder has total parameter number: 1.02 M
# Epoch   0 / 20 train_loss: 0.000881 | val_loss: 0.000729 | lr: 0.001
# Epoch   1 / 20 train_loss: 0.000644 | val_loss: 0.001295 | lr: 0.001
# Epoch   2 / 20 train_loss: 0.000636 | val_loss: 0.000549 | lr: 0.001
# Epoch   3 / 20 train_loss: 0.000583 | val_loss: 0.000595 | lr: 0.001
# Epoch   4 / 20 train_loss: 0.000592 | val_loss: 0.000711 | lr: 0.001
# Epoch   5 / 20 train_loss: 0.000567 | val_loss: 0.000511 | lr: 0.001
# Epoch   6 / 20 train_loss: 0.000509 | val_loss: 0.000606 | lr: 0.001
# Epoch   7 / 20 train_loss: 0.000505 | val_loss: 0.000550 | lr: 0.001
# Epoch   8 / 20 train_loss: 0.000509 | val_loss: 0.000469 | lr: 0.001
# Epoch   9 / 20 train_loss: 0.000513 | val_loss: 0.000477 | lr: 0.001
# Epoch  10 / 20 train_loss: 0.000537 | val_loss: 0.000686 | lr: 0.001
# Epoch  11 / 20 train_loss: 0.000504 | val_loss: 0.000463 | lr: 0.001
# Epoch  12 / 20 train_loss: 0.000476 | val_loss: 0.000461 | lr: 0.001
# Epoch  13 / 20 train_loss: 0.000524 | val_loss: 0.000692 | lr: 0.001
# Epoch  14 / 20 train_loss: 0.000524 | val_loss: 0.000558 | lr: 0.001
# Epoch  15 / 20 train_loss: 0.000483 | val_loss: 0.000522 | lr: 0.001
# Epoch  16 / 20 train_loss: 0.000475 | val_loss: 0.000670 | lr: 0.0005
# Epoch  17 / 20 train_loss: 0.000444 | val_loss: 0.000432 | lr: 0.0005
# Epoch  18 / 20 train_loss: 0.000429 | val_loss: 0.000411 | lr: 0.0005
# Epoch  19 / 20 train_loss: 0.000426 | val_loss: 0.000452 | lr: 0.0005
# Model saved to sim2_iter2_best_model.pth
# Model ShapeAwareAutoencoder has total parameter number: 1.02 M
# MAD cutoff for reconstruction error: 0.0005220844177529216
# MAD cutoff for Lzc: 79.0
# Number of inconsistent reads: 5028
# Number of clean reads: 14972
# Iteration 1/3 for training ShapeAwareAutoencoder...
# Model ShapeAwareAutoencoder has total parameter number: 1.02 M
# Epoch   0 / 20 train_loss: 0.025793 | val_loss: 0.006027 | lr: 0.001
# Epoch   1 / 20 train_loss: 0.005020 | val_loss: 0.006074 | lr: 0.001
# Epoch   2 / 20 train_loss: 0.004281 | val_loss: 0.003866 | lr: 0.001
# Epoch   3 / 20 train_loss: 0.003842 | val_loss: 0.005754 | lr: 0.001
# Epoch   4 / 20 train_loss: 0.003455 | val_loss: 0.002888 | lr: 0.001
# Epoch   5 / 20 train_loss: 0.002686 | val_loss: 0.003624 | lr: 0.001
# Epoch   6 / 20 train_loss: 0.002528 | val_loss: 0.002586 | lr: 0.001
# Epoch   7 / 20 train_loss: 0.002452 | val_loss: 0.004894 | lr: 0.001
# Epoch   8 / 20 train_loss: 0.002121 | val_loss: 0.002456 | lr: 0.001
# Epoch   9 / 20 train_loss: 0.001765 | val_loss: 0.002761 | lr: 0.001
# Epoch  10 / 20 train_loss: 0.001796 | val_loss: 0.001643 | lr: 0.001
# Epoch  11 / 20 train_loss: 0.001683 | val_loss: 0.001452 | lr: 0.001
# Epoch  12 / 20 train_loss: 0.001684 | val_loss: 0.001415 | lr: 0.001
# Epoch  13 / 20 train_loss: 0.001645 | val_loss: 0.001599 | lr: 0.001
# Epoch  14 / 20 train_loss: 0.001864 | val_loss: 0.002920 | lr: 0.001
# Epoch  15 / 20 train_loss: 0.001590 | val_loss: 0.001400 | lr: 0.001
# Epoch  16 / 20 train_loss: 0.001700 | val_loss: 0.001677 | lr: 0.001
# Epoch  17 / 20 train_loss: 0.001664 | val_loss: 0.006599 | lr: 0.001
# Epoch  18 / 20 train_loss: 0.001671 | val_loss: 0.001390 | lr: 0.001
# Epoch  19 / 20 train_loss: 0.001438 | val_loss: 0.001242 | lr: 0.001
# Iteration 2/3 for training ShapeAwareAutoencoder...
# Model ShapeAwareAutoencoder has total parameter number: 1.02 M
# Epoch   0 / 20 train_loss: 0.000881 | val_loss: 0.000729 | lr: 0.001
# Epoch   1 / 20 train_loss: 0.000644 | val_loss: 0.001295 | lr: 0.001
# Epoch   2 / 20 train_loss: 0.000636 | val_loss: 0.000549 | lr: 0.001
# Epoch   3 / 20 train_loss: 0.000583 | val_loss: 0.000595 | lr: 0.001
# Epoch   4 / 20 train_loss: 0.000592 | val_loss: 0.000711 | lr: 0.001
# Epoch   5 / 20 train_loss: 0.000567 | val_loss: 0.000511 | lr: 0.001
# Epoch   6 / 20 train_loss: 0.000509 | val_loss: 0.000606 | lr: 0.001
# Epoch   7 / 20 train_loss: 0.000505 | val_loss: 0.000550 | lr: 0.001
# Epoch   8 / 20 train_loss: 0.000509 | val_loss: 0.000469 | lr: 0.001
# Epoch   9 / 20 train_loss: 0.000513 | val_loss: 0.000477 | lr: 0.001
# Epoch  10 / 20 train_loss: 0.000537 | val_loss: 0.000686 | lr: 0.001
# Epoch  11 / 20 train_loss: 0.000504 | val_loss: 0.000463 | lr: 0.001
# Epoch  12 / 20 train_loss: 0.000476 | val_loss: 0.000461 | lr: 0.001
# Epoch  13 / 20 train_loss: 0.000524 | val_loss: 0.000692 | lr: 0.001
# Epoch  14 / 20 train_loss: 0.000524 | val_loss: 0.000558 | lr: 0.001
# Epoch  15 / 20 train_loss: 0.000483 | val_loss: 0.000522 | lr: 0.001
# Epoch  16 / 20 train_loss: 0.000475 | val_loss: 0.000670 | lr: 0.0005
# Epoch  17 / 20 train_loss: 0.000444 | val_loss: 0.000432 | lr: 0.0005
# Epoch  18 / 20 train_loss: 0.000429 | val_loss: 0.000411 | lr: 0.0005
# Epoch  19 / 20 train_loss: 0.000426 | val_loss: 0.000452 | lr: 0.0005
# Iteration 3/3 for training ShapeAwareAutoencoder...
# Model ShapeAwareAutoencoder has total parameter number: 1.02 M
# Epoch   0 / 20 train_loss: 0.000606 | val_loss: 0.000833 | lr: 0.001
# Epoch   1 / 20 train_loss: 0.000443 | val_loss: 0.000490 | lr: 0.001
# Epoch   2 / 20 train_loss: 0.000426 | val_loss: 0.000431 | lr: 0.001
# Epoch   3 / 20 train_loss: 0.000429 | val_loss: 0.000451 | lr: 0.001
# Epoch   4 / 20 train_loss: 0.000437 | val_loss: 0.000797 | lr: 0.001
# Epoch   5 / 20 train_loss: 0.000434 | val_loss: 0.000418 | lr: 0.001
# Epoch   6 / 20 train_loss: 0.000420 | val_loss: 0.000617 | lr: 0.001
# Epoch   7 / 20 train_loss: 0.000438 | val_loss: 0.000455 | lr: 0.001
# Epoch   8 / 20 train_loss: 0.000435 | val_loss: 0.000498 | lr: 0.001
# Epoch   9 / 20 train_loss: 0.000433 | val_loss: 0.000542 | lr: 0.0005
# Epoch  10 / 20 train_loss: 0.000405 | val_loss: 0.000425 | lr: 0.0005
# Epoch  11 / 20 train_loss: 0.000400 | val_loss: 0.000411 | lr: 0.0005
# Epoch  12 / 20 train_loss: 0.000395 | val_loss: 0.000518 | lr: 0.0005
# Epoch  13 / 20 train_loss: 0.000397 | val_loss: 0.000423 | lr: 0.0005
# Epoch  14 / 20 train_loss: 0.000399 | val_loss: 0.000422 | lr: 0.0005
# Epoch  15 / 20 train_loss: 0.000402 | val_loss: 0.000399 | lr: 0.0005
# Epoch  16 / 20 train_loss: 0.000399 | val_loss: 0.000408 | lr: 0.0005
# Epoch  17 / 20 train_loss: 0.000401 | val_loss: 0.000402 | lr: 0.0005
# Epoch  18 / 20 train_loss: 0.000399 | val_loss: 0.000402 | lr: 0.0005
# Epoch  19 / 20 train_loss: 0.000401 | val_loss: 0.000444 | lr: 0.00025
# Number of reads after iteration 3: 9959. Stopping training as it is less than 10000.
# Model saved to sim2_iter3_best_model.pth
# Model ShapeAwareAutoencoder has total parameter number: 1.02 M
# MAD cutoff for reconstruction error: 0.0005236263386905193
# MAD cutoff for Lzc: 79.0
# Number of inconsistent reads: 4777
# Number of clean reads: 15223

# %%
cm_dfs_dict = {}
for iteration in range(1,4):
    cm_df = npsc.get_cm_from_errors_for_sim(f'../../03.results/simulation/{sim}/iter{iteration}/{sim}_iter{iteration}_error.csv')
    cm_dfs_dict[iteration] = cm_df
cm_dfs_dict
# Out:
# {1: pred    target  noise
#  true
#  target   18000      0
#  noise        0   2000,
#  2: pred    target  noise
#  true
#  target   17999      1
#  noise        1   1999,
#  3: pred    target  noise
#  true
#  target   18000      0
#  noise        0   2000}

# %%
for iteration, cm_df in cm_dfs_dict.items():
    nps.ml.plot_cm(cm_df, figsize=(2, 1.7), annot_size=12.0)
    plt.xticks(fontsize=12)
    plt.yticks(fontsize=12)
    plt.savefig(f"../../05.figures/simulation/{sim}/{sim}_iter{iteration}_cm.pdf", bbox_inches='tight')

# %%
metrics_dfs = []
for iteration in range(1,4):
    metrics_df = npsc.get_metrics_from_errors_for_sim(f'../../03.results/simulation/{sim}/iter{iteration}/{sim}_iter{iteration}_error.csv')
    metrics_df.index = [f'iter{iteration}']
    metrics_dfs.append(metrics_df)
metrics_dfs = pd.concat(metrics_dfs)
metrics_dfs
# Out:
#        accuracy  precision    recall  f1_score  jaccard_score
# iter1    1.0000   1.000000  1.000000  1.000000       1.000000
# iter2    0.9999   0.999722  0.999722  0.999722       0.999445
# iter3    1.0000   1.000000  1.000000  1.000000       1.000000

# %%
npsc.draw_radar_plot(metrics_dfs, y_min=0.8, legned_ncol=1, figsize=(4,4), y_tick_num=4,)
plt.savefig(f'../../05.figures/simulation/{sim}/{sim}_radar_plot.pdf', bbox_inches='tight')
