# %%
# %load_ext autoreload
# %autoreload 2
import sys
import os
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib as mpl
mpl.rcParams['pdf.fonttype'] = 42
mpl.rcParams['ps.fonttype'] = 42
mpl.rcParams['font.sans-serif'] = "Arial"
mpl.rcParams['font.family'] = "sans-serif"
import time
import glob
import re
import random
import torch

sys.path.insert(0, '/Data/uesr/panhailin/git_lab/npspy')
import npspy as nps
from npspy import npsc

# %%
all_peps = ['1A', '1C', '1D', '1E', '1F', '1G', '1H', '1I', '1K', '1L', '1M', '1N', '1P', '1Q', '1R', '1S', '1T', '1V', '1W', '1Y']

# %%
for pep in all_peps:
    npsc.clean_ref_obj_by_ae_and_save(
        obj=f'../../../00.data/GSXGS/{pep}_valid80.pkl',
        fit_name=f'{pep}_valid80',
        output_save_dir=f'../../../03.results/classification_on_clean_data/GSXGS/{pep}/',
        weight_decay=1e-5,
    )

    npsc.clean_an_obj_with_trained_model(
        obj=f'../../../00.data/GSXGS/{pep}_valid20.pkl',
        save_dir=f'../../../03.results/classification_on_clean_data/GSXGS/{pep}',
        save_name=f'{pep}_valid20',
        fit_name=f'{pep}_valid80',
        error_threshold_file=f'../../../03.results/classification_on_clean_data/GSXGS/{pep}/{pep}_valid80_error_threshold.csv',
        lzc_threshold_file=f'../../../03.results/classification_on_clean_data/GSXGS/{pep}/{pep}_valid80_lzc_threshold.csv',
    )
# Out:
# Iteration 1/3 for training ShapeAwareAutoencoder...
# Model ShapeAwareAutoencoder has total parameter number: 1.02 M
# Epoch   0 / 20 train_loss: 0.003707 | val_loss: 0.001840 | lr: 0.001
# Epoch   1 / 20 train_loss: 0.001543 | val_loss: 0.001535 | lr: 0.001
# Epoch   2 / 20 train_loss: 0.001402 | val_loss: 0.002810 | lr: 0.001
# Epoch   3 / 20 train_loss: 0.001314 | val_loss: 0.001620 | lr: 0.001
# Epoch   4 / 20 train_loss: 0.001263 | val_loss: 0.001815 | lr: 0.001
# Epoch   5 / 20 train_loss: 0.001215 | val_loss: 0.001158 | lr: 0.001
# Epoch   6 / 20 train_loss: 0.001190 | val_loss: 0.001325 | lr: 0.001
# Epoch   7 / 20 train_loss: 0.001156 | val_loss: 0.001489 | lr: 0.001
# Epoch   8 / 20 train_loss: 0.001165 | val_loss: 0.001072 | lr: 0.001
# Epoch   9 / 20 train_loss: 0.001112 | val_loss: 0.001568 | lr: 0.001
# Epoch  10 / 20 train_loss: 0.001087 | val_loss: 0.001168 | lr: 0.001
# Epoch  11 / 20 train_loss: 0.001071 | val_loss: 0.001516 | lr: 0.001
# ...

# %%
all_peps = [
    '1pS', '1SMe', '3SMe', '1SAc', '3SAc', '1Soct', '3Soct', 
    '3I', '3L', '3dI', '3dL', '1D02', '1R02', '1Y02', '1W02',
]

# %%
for pep in all_peps:
    npsc.clean_ref_obj_by_ae_and_save(
        obj=f'../../../00.data/GSXGS/{pep}_valid80.pkl',
        fit_name=f'{pep}_valid80',
        output_save_dir=f'../../../03.results/classification_on_clean_data/GSXGS/{pep}/',
        weight_decay=1e-5,
    )

    npsc.clean_an_obj_with_trained_model(
        obj=f'../../../00.data/GSXGS/{pep}_valid20.pkl',
        save_dir=f'../../../03.results/classification_on_clean_data/GSXGS/{pep}',
        save_name=f'{pep}_valid20',
        fit_name=f'{pep}_valid80',
        error_threshold_file=f'../../../03.results/classification_on_clean_data/GSXGS/{pep}/{pep}_valid80_error_threshold.csv',
        lzc_threshold_file=f'../../../03.results/classification_on_clean_data/GSXGS/{pep}/{pep}_valid80_lzc_threshold.csv',
    )
# Out:
# Iteration 1/3 for training ShapeAwareAutoencoder...
# Model ShapeAwareAutoencoder has total parameter number: 1.02 M
# Epoch   0 / 20 train_loss: 0.005129 | val_loss: 0.003583 | lr: 0.001
# Epoch   1 / 20 train_loss: 0.002223 | val_loss: 0.001844 | lr: 0.001
# Epoch   2 / 20 train_loss: 0.001685 | val_loss: 0.001891 | lr: 0.001
# Epoch   3 / 20 train_loss: 0.001509 | val_loss: 0.002008 | lr: 0.001
# Epoch   4 / 20 train_loss: 0.001458 | val_loss: 0.001751 | lr: 0.001
# Epoch   5 / 20 train_loss: 0.001356 | val_loss: 0.001409 | lr: 0.001
# Epoch   6 / 20 train_loss: 0.001309 | val_loss: 0.001565 | lr: 0.001
# Epoch   7 / 20 train_loss: 0.001318 | val_loss: 0.001311 | lr: 0.001
# Epoch   8 / 20 train_loss: 0.001264 | val_loss: 0.001302 | lr: 0.001
# Epoch   9 / 20 train_loss: 0.001247 | val_loss: 0.001483 | lr: 0.001
# Epoch  10 / 20 train_loss: 0.001229 | val_loss: 0.001398 | lr: 0.001
# Epoch  11 / 20 train_loss: 0.001183 | val_loss: 0.001240 | lr: 0.001
# ...
